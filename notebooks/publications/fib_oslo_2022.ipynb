# %%
# %matplotlib widget
# %matplotlib qt
import matplotlib.pyplot as plt
import numpy as np
import bmcs_utils.api as bu
from bmcs_cross_section.api import MKappa, TShape, CustomShape, EC2, BarLayer, ReinfLayer
from bmcs_beam.api import SLSParamStudy, BoundaryConditions, BoundaryConfig, DeflectionProfile, BeamDesign, BeamSLSCurve, LoadDeflectionParamsStudy
from mpl_toolkits import mplot3d

# %% [markdown]
# # Flexural response

# %%
# Concrete C3-HF2-165-4
E_cm_C3 = 43596
f_cm_C3 = 103
fctm_sp = 5.6
fctm_fl = 12.51

# solidian REBAR Ø6 and Ø8
A_phi_6 = 28.2
A_phi_8 = 50.2

# Params study
# Concrete class (according to fib model code)
# C40: f_cm = 48, E_cm = 36300
# C70: f_cm = 78, E_cm = 42600
# C100: f_cm = 108, E_cm = 47500

# z: 20, 50, 80

# B: 200, 500, 800
# H: 100, 300, 500, 700

# concrete: C40
def get_dp(f_cm = 48, E_cm = 36300, 
           setup='dist', L=2000, L_F=None,
           high_kappa = 0.0001, concrete_law='EC2',
           B=200, H=300, A = None,
           reinf = 'carbon',
           E_nm=None, f_t=None, z=20,
           carbon_type='rebars',
           grid_layers_n=1, grid_layers_spacing=10, grid_layers_area=[]):
    # carbon_type: 'rebars' -> solidian REBAR Ø8-CCE
    # carbon_type: 'grid' -> solidian GRID Q95-CCE-38-E5
    
    mc = MKappa(low_kappa = 0, high_kappa = high_kappa)
    
    mc.cs_design.matrix=concrete_law
    
    f_ck = EC2.get_f_ck_from_f_cm(f_cm)
    fctm_fl = EC2.get_f_ctm_fl(f_ck, H)
    if concrete_law == 'EC2 with plateau' or concrete_law == 'EC2':
        mc.cs_design.matrix_.trait_set(f_cm = f_cm)
    elif concrete_law == 'piecewise linear':
        mc.cs_design.matrix_.trait_set(
            eps_cy=EC2.get_eps_c3(f_ck),
            eps_cu=EC2.get_eps_cu3(f_ck),
        )
    
    mc.cs_design.matrix_.trait_set(E_cc=E_cm, 
                                   E_ct=E_cm, 
                                   eps_cr = fctm_fl/E_cm, 
                                   eps_tu = fctm_fl/E_cm,)

    mc.cross_section_shape_.B = B
    mc.cross_section_shape_.H = H

    if carbon_type == 'rebars':
        E_nm=158000 if E_nm is None else E_nm
        f_t=2500 if f_t is None else f_t
        if A is None:
            A = 4 * A_phi_8
        if z is None:
            z = 4 + 10
    elif carbon_type == 'grid':
        E_nm=230000 if E_nm is None else E_nm
        f_t=3300 if f_t is None else f_t
        
        spacing = 38
        rov_num = int(B/spacing) + 1
        rov_cs_area = 3.62

        if A is None:
            A = rov_num * rov_cs_area
        if z is None:
            z = 10
       
    d = H - z
    
    if reinf == 'carbon':
        if grid_layers_n == 1:
            bl1 = ReinfLayer(name=carbon_type, z=z, A=A, matmod='carbon')
            bl1.matmod_.trait_set(E=E_nm, f_t=f_t, factor = 1.)
            mc.cross_section_layout.add_layer(bl1)
        else:
            for i in range(grid_layers_n):
                if grid_layers_area:
                    bl1 = ReinfLayer(name=carbon_type, z=z + i*grid_layers_spacing, A=grid_layers_area[i], matmod='carbon')
                else:
                    bl1 = ReinfLayer(name=carbon_type, z=z + i*grid_layers_spacing, A=A, matmod='carbon')
                bl1.matmod_.trait_set(E=E_nm, f_t=f_t, factor = 1.)
                mc.cross_section_layout.add_layer(bl1)
            A = grid_layers_n * A
    else:
        bl1 = ReinfLayer(name='rebars', z=z, A=A, matmod='steel')
        mc.cross_section_layout.add_layer(bl1)

    rho = A/(B*d)
    print('A=', A)
    print(r'rho =', round(rho * 100, 2), r'%')
    # mechanical reinforcement ratio
#     w_m = A * f_t / (B * H * f_cm)
#     print('w_m:', w_m)

    dp = DeflectionProfile(mc=mc)
    
    if setup == '4pb':
        dp.beam_design.system = '4pb'
        if L_F is not None:
            print('L_F assigned!')
            dp.beam_design.system_.L_F = L_F
    elif setup == '3pb':
        dp.beam_design.system = '3pb'
    elif setup == 'dist':
        dp.beam_design.system = 'simple_beam_dist_load'
        
    dp.beam_design.system_.L = L
    
    print('l/d =', dp.beam_design.system_.L/d)
    
    return dp

# %%
def apply_t_shape(dp):
    dp.mc.cross_section_shape = 'I-shape'
    dp.mc.cross_section_shape_.H = 300
    dp.mc.cross_section_shape_.B_w = 100
    dp.mc.cross_section_shape_.B_f_bot = 100
    dp.mc.cross_section_shape_.B_f_top = 400
    dp.mc.cross_section_shape_.H_f_bot = 100
    dp.mc.cross_section_shape_.H_f_top = 100
    
def apply_i_shape(dp):
    dp.mc.cross_section_shape = 'custom'
    dp.mc.cross_section_shape_.cs_points = np.array([   [60, 0],
                                                        [60, 40],
                                                        [25, 72.5],
                                                        [25, 145],
                                                        [200, 220],
                                                        [200, 300],
                                                        [-200, 300],
                                                        [-200, 220],
                                                        [-25, 145],
                                                        [-25, 72.5],
                                                        [-60, 40],
                                                        [-60, 0]])
def get_dp_hybrid():
    dp_c = get_dp(reinf = 'carbon', carbon_type='rebars')
    dp_s = get_dp(reinf = 'steel')
    steel_layer = dp_s.mc.cross_section_layout.items[0]
    dp_c.mc.cross_section_layout.add_layer(steel_layer)
    return dp_c

# %% [markdown]
# ## Hybrid

# %%
dp_h = get_dp_hybrid()

# NOTE: BeamSLSCurve doesn't work now for multiple layers!
# sls_h = BeamSLSCurve(n_i = 16, dp=dp_h)
# sls_h.run()

# dp_h.interact()
# Out:
# A= 200.8
# rho = 0.36 %
# l/d = 7.142857142857143
# A= 200.8
# rho = 0.36 %
# l/d = 7.142857142857143

# %% [markdown]
# ### Get ($\rho$ vs $M_{max}$, $\sigma_{r, max}$, $\sigma_{c, max}$) diagrams

# %%
fig = dp_h.mc.plot_M_rho_and_stress_rho(n_rho = 50, reinf_layers_rho_factors=[0.2, 0.8])
# fig.savefig('hybrid_psi_ratios_factors_0.2_0.8.pdf')
fig
# Out:
# Non regular rho_list was created (denser up to rho = 0.4%).
# Conc. normalized by max_c =  47.999998138897425
# (<Figure size 550x680 with 3 Axes>,
#  (<AxesSubplot:xlabel='Reinforcement ratio $\\rho$', ylabel='$M_\\mathrm{u}$ [kNm]'>,
#   <AxesSubplot:xlabel='Reinforcement ratio $\\rho$', ylabel='Concrete utilization ratio $\\psi_c$'>))
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Carbon

# %%
# Just for fib presentation

dp = get_dp(A=0.007*280*200, high_kappa=0.00005)
dp.mc.n_m = 700
dp.mc.n_kappa = 500

plt.rcParams.update({'font.size': 14})

for i, k in enumerate(np.linspace(0, 0.000046, 100)):
    fig, pl_axes = plt.subplots(1, 3)
    
    fig.tight_layout(pad=0.8)
    fig.set_size_inches(10, 3.2)

    dp.mc.kappa_slider = k

    axes = dp.mc.plot_mk_and_stress_profile(*pl_axes[0:2])
    axes[0].get_legend().remove()
    axes[2].set_xlim(-52, 52)
    axes[1].set_xlim(-1500, 1500)
    
    
    dp.mc.plot_strain_profile(pl_axes[2])
    pl_axes[2].set_xlim(-0.012, 0.012)

    fig.savefig('anim_' + str(i) + '.png', dpi=250, bbox_inches='tight')
fig
# Out:
# A= 392.0
# rho = 0.7 %
# l/d = 7.142857142857143
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 9>()
#      15 dp.mc.kappa_slider = k
#      17 axes = dp.mc.plot_mk_and_stress_profile(*pl_axes[0:2])
# ---> 18 axes[0].get_legend().remove()
#      19 axes[2].set_xlim(-52, 52)
#      20 axes[1].set_xlim(-1500, 1500)
#
# TypeError: 'NoneType' object is not subscriptable
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(3, 3)
dp.plot_fw(ax)
# fig
# fig.savefig('carbon_sl_10_rho_2.pdf')

# %%
ax.axhline(y=984)

# %%
fig

# %%
dp = get_dp()

# apply_t_shape(dp)
# apply_i_shape(dp)

# sls = BeamSLSCurve(n_i = 16, dp=dp)
# sls.run()
dp.interact()
# Out:
# A= 200.8
# rho = 0.36 %
# l/d = 7.142857142857143
# V_Rm_c = 54.91 kN, Shear failure by F_tot_max = 109.82 kN
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…
# V_Rm_c = 54.91 kN, Shear failure by F_tot_max = 109.82 kN

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(3, 3)
# dp.plot_fw(ax)
# fig
# # fig.savefig('carbon_sl_10_rho_2.pdf')

# %%
# levels = [0, 10, 20, 30, 40, 50, 65, 80, 100, 150, 300, 800, 1000]

fig = sls.plot_F_u()
# fig.set_size_inches(5.5, 4.2)

# fig = sls.plot_F_u(bending_shear_diff = True)
# fig = sls.plot_F_u(load='shear')
fig
fig.savefig('Default_setup_carbon_F_max.pdf')

# %% [markdown]
# ### Get ($\rho$ vs $M_{max}$, $\sigma_{r, max}$, $\sigma_{c, max}$) diagrams

# %%
fig = dp.mc.plot_M_rho_and_stress_rho(n_rho = 2)
fig
# fig.savefig('I_beam_carbon.pdf')
# Out:
# Conc. normalized by max_c =  47.984083734758975
# Reinf. normalized by f_ult =  2500.0

# %% [markdown]
# ### Get MK for specific $\rho$ values

# %%
# TODO, I should increase high_kappa for carbon results and redo them, with 0.00125 not the full result is obtainable with the current high_kappa
fig_mk, ax_mk = plt.subplots()
fig_mk.set_size_inches(2.7, 2.2)
rho = 0.02 # 0.02 and 0.005, 0.0002
dp.mc.n_kappa = 400
dp.mc.plot_mk_for_rho(rho, ax = ax_mk)
fig_mk.show()

matmod = dp.mc.cross_section_layout.items[0].matmod
fig_mk.savefig('Default_setup_' + matmod + '_MK_rho_' + str(rho) + '.pdf')

# %% [markdown]
# ### Balance reinforcement ratio $\rho_{\mathrm{fb}}$ according to ACI 440.1R-15

# %%
get_beta_1 = lambda f_cm : 0.85 if f_cm <= 28 else max((0.85 - 0.05 * (f_cm-28) / 7), 0.65)

def get_rho_fb(f_fu = 2500, E_f = 158000, f_cm = 48):
    eps_cu = EC2.get_eps_cu1(f_cm - 8)
    beta_1 = get_beta_1(f_cm)
    rho_fb = 0.85 * beta_1 * (f_cm/f_fu) * (E_f * eps_cu/(E_f * eps_cu + f_fu))
    return rho_fb

get_rho_fb()
# Out:
# 0.0020903819194235175

# %% [markdown]
# ### Flexural strength according to ACI 440.1R-15

# %% [markdown]
# **1. $\rho_f < \rho_{fb}$ (FRP rupture case), conservative approach to avoid intesive calculation**

# %%
def get_M_n_rupture(A_f = 50, f_fu = 2500, E_f = 158000, f_cm = 48, d=280):
    eps_cu = EC2.get_eps_cu1(f_cm - 8)
    beta_1 = get_beta_1(f_cm)
    eps_fu = f_fu/E_f
    c_b = (eps_cu/(eps_cu + eps_fu)) * d
    M_n = A_f * f_fu * (d - beta_1 * c_b/2) /1e6
    return M_n
get_M_n_rupture()
# Out:
# 32.75847527022601

# %% [markdown]
# **2. $\rho_f > \rho_{fb}$ (concrete crushing case)**

# %% [markdown]
# **Option 1:**

# %%
def get_M_n_comp_1(A_f = 1400):
    f_fu = 2500
    E_f = 158000
    f_cm = 48
    eps_cu = EC2.get_eps_cu1(f_cm - 8)
    d = 280
    b = 200
    rho_f = A_f / (b * d)
    beta_1 = get_beta_1(f_cm)
    f_f = np.minimum(np.sqrt(((E_f * eps_cu)**2)/4 + 0.85 * beta_1 * f_cm * E_f * eps_cu / rho_f) - 0.5 * E_f * eps_cu, f_fu)
    a = A_f * f_f/(0.85 * f_cm * b)
    M_n = A_f * f_f * (d - a/2) /1e6
    return M_n
get_M_n_comp_1()
# Out:
# 184.13105121873355

# %% [markdown]
# **Option 2:**

# %%
M_n = (rho_f * f_f * (1-0.59 * rho_f * f_f / f_cm) * b * d**2)/1e6
M_n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21868/1660645541.py in <module>
# ----> 1 M_n = (rho_f * f_f * (1-0.59 * rho_f * f_f / f_cm) * b * d**2)/1e6
#       2 M_n
#
# NameError: name 'rho_f' is not defined

# %%
n_rho = 50
rho_fb = get_rho_fb()
rho_list = np.linspace(0.0002, 0.025, n_rho)
b = 200
d = 280
M_n = np.where(rho_list < rho_fb, get_M_n_rupture(A_f=rho_list*b*d), get_M_n_comp_1(A_f=rho_list*b*d))


fig, ax = plt.subplots()
fig.set_size_inches(5.5, 3.4)
M_max = M_n[-1]
ax.axhline(y=M_max, color='r')
ax.annotate(r'$M_{\mathrm{max, ' + str(rho_list[-1]) + '}} = ' + str(round(M_max, 2)) + '$ kNm',
               xy=(0, 1.04 * M_max), color='r')
ax.plot(rho_list, M_n)
fig.savefig('Default_setup_M_rho_ACI_carbon.pdf')
fig

# %% [markdown]
# ## Steel

# %%
dp2 = get_dp(reinf='steel', high_kappa=0.00005)

# apply_t_shape(dp2)
# apply_i_shape(dp2)

# sls2 = BeamSLSCurve(n_i = 16, dp=dp2)
# sls2.run()
dp2.interact()
# sls2.interact()
# Out:
# A= 200.8
# rho = 0.36 %
# l/d = 7.142857142857143
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…

# %%
# fig, ax = plt.subplots()
# fig.set_size_inches(3, 3)
# sls2.dp.plot_fw(ax)
# fig.savefig('steel_sl_10_rho_2.pdf')

# %%
sls2.dp.interact()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…

# %%
fig = sls2.plot_F_u()
# fig.set_size_inches(5.5, 4.2)
fig.savefig('Default_setup_steel_F_max.pdf')
fig
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Get ($\rho$ vs $M_{max}$, $\sigma_{r, max}$, $\sigma_{c, max}$) diagrams

# %%
fig.savefig('I_beam_steel.pdf')

# %%
fig = dp2.mc.plot_M_rho_and_stress_rho(n_rho = 50)
fig
# fig.savefig('T_beam_steel.pdf')
# Out:
# Conc. normalized by max_c =  34.49998962217034
# Reinf. normalized by f_ult =  414.0

# %%
dp2.mc.interact()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…

# %% [markdown]
# ### Get MK for specific $\rho$ values

# %%
# TODO, I should increase high_kappa for carbon results and redo them, with 0.00125 not the full result is obtainable with the current high_kappa
fig_mk, ax_mk = plt.subplots()
fig_mk.set_size_inches(2.7, 2.2)
dp2.mc.high_kappa = 0.00005
rho = 0.0002 # 0.02 and 0.005, 0.0002
dp2.mc.n_kappa = 400
dp2.mc.plot_mk_for_rho(rho, ax = ax_mk)
fig_mk.show()

matmod = dp2.mc.cross_section_layout.items[0].matmod
fig_mk.savefig('Default_setup_' + matmod + '_MK_rho_' + str(rho) + '.pdf')

# %% [markdown]
# ### $M_{max, carbon}/M_{max, steel}$

# %%
fig.savefig('T_beam_steel_carbon.pdf')

# %%
fig = dp2.mc.plot_M_rho_to_M_rho_for_other_mc(n_rho = 60, mc=dp.mc)
fig

# %% [markdown]
# ### $M_{max, hybrid}/M_{max, steel}$

# %%
fig = dp2.mc.plot_M_rho_to_M_rho_for_other_mc(n_rho = 50, mc=dp_h.mc, mc_reinf_layers_rho_factors=[0.2, 0.8])
fig.savefig('hybrid_to_steel_ratio_hybrid_factors_0.2_0.8.pdf')
fig

# %% [markdown]
# ### Balance reinforcement ratio $\rho_{\mathrm{b}}$ according to ACI 318-95
# (ACI defines balanced reinforcement ratio for steel as when "Steel yields just as concrete crushes", in my calculation it could happen that steel yields a lot then comes the concrete crush.)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
f_cm = 48
beta_1 = get_beta_1(f_cm)
f_sy = 500
E_s = 200000
eps_sy = f_sy/E_s
eps_cu = EC2.get_eps_cu1(f_cm-8) # usually 0.003 according to ACI
rho_b = 0.85 * beta_1 * (f_cm/f_sy) * (eps_cu/(eps_cu + eps_sy))
rho_b
# Out:
# 0.033659999999999995

# %% [markdown]
# ### Flexural strength according to ACI 318M-19

# %%
A_s = 1200
d = 280
b = 200
a = A_s * f_sy/(0.85 * f_cm * b)
M_n = A_s * f_sy * (d - a/2) /1e6
M_n
# Out:
# 145.94117647058823

# %% [markdown]
# ### Effect of different concrete grade on $M_u$ according to ACI code

# %%
n_rho = 50

def get_M_u_steel(f_cm = 48, rho_list = np.linspace(0.0002, 0.025, n_rho)):
    n_rho = 50
    b = 200
    d = 280
    f_sy = 500
    a = (rho_list * b * d) * f_sy/(0.85 * f_cm * b)
    M_n = rho_list * b * d * f_sy * (d - a/2) /1e6
    return M_n

fig, ax = plt.subplots()
fig.set_size_inches(5.5, 3.4)

rho_list = np.linspace(0.0002, 0.025, n_rho)
for f_cm in [48, 108]:
    M_n = get_M_u_steel(f_cm=f_cm, rho_list=rho_list)
    M_max = M_n[-1]
    ax.axhline(y=M_max, color='r')
    ax.annotate(r'$M_{\mathrm{max, ' + str(rho_list[-1]) + '}} = ' + str(round(M_max, 2)) + '$ kNm',
                   xy=(0, 1.04 * M_max), color='r')
    ax.plot(rho_list, M_n)
fig.savefig('Default_setup_M_rho_ACI_steel.pdf')
fig

# %% [markdown]
# # SLS Study

# %% [markdown]
# ![Load-deflection-2.svg](attachment:Load-deflection-2.svg)
# $q_{GZT}$ = F_u in the code\
# $q_{GZG}$ = F_s in the code\
# $\gamma_{carbon}$ 1.3/(0.85*0.9)

# %% [markdown]
# ## Carbon

# %%
b_sls = BeamSLSCurve(n_i = 16, rein_type = 'carbon_grid', f_ck=40) #, rein_type = 'steel'
ps = SLSParamStudy(b_sls)
b_sls.run()
# b_sls.apply_material_factors = False # I didn't apply them for carbon
# b_sls.use_f_ctm_fl = False
# b_sls.concrete_law = 'EC2 with plateau'
# Out:
# dp updated!
# dp updated!
# run started...
# parameter combination 0.0002 3.0
# parameter combination 0.0002 6.133333333333333
# parameter combination 0.0002 9.266666666666666
# parameter combination 0.0002 12.4
# parameter combination 0.0002 15.533333333333333
# parameter combination 0.0002 18.666666666666664
# parameter combination 0.0002 21.8
# parameter combination 0.0002 24.933333333333334
# parameter combination 0.0002 28.066666666666666
# parameter combination 0.0002 31.2
# parameter combination 0.0002 34.33333333333333
# parameter combination 0.0002 37.46666666666667
# parameter combination 0.0002 40.6
# parameter combination 0.0002 43.733333333333334
# parameter combination 0.0002 46.86666666666667
# parameter combination 0.0002 50.0
# parameter combination 0.0018533333333333336 3.0
# parameter combination 0.0018533333333333336 6.133333333333333
# parameter combination 0.0018533333333333336 9.266666666666666
# parameter combination 0.0018533333333333336 12.4
# parameter combination 0.0018533333333333336 15.533333333333333
# parameter combination 0.0018533333333333336 18.666666666666664
# parameter combination 0.0018533333333333336 21.8
# parameter combination 0.0018533333333333336 24.933333333333334
# parameter combination 0.0018533333333333336 28.066666666666666
# parameter combination 0.0018533333333333336 31.2
# parameter combination 0.0018533333333333336 34.33333333333333
# parameter combination 0.0018533333333333336 37.46666666666667
# parameter combination 0.0018533333333333336 40.6
# parameter combination 0.0018533333333333336 43.733333333333334
# parameter combination 0.0018533333333333336 46.86666666666667
# parameter combination 0.0018533333333333336 50.0
# parameter combination 0.003506666666666667 3.0
# parameter combination 0.003506666666666667 6.133333333333333
# parameter combination 0.010120000000000002 24.933333333333334
# parameter combination 0.010120000000000002 28.066666666666666
# parameter combination 0.010120000000000002 31.2
# parameter combination 0.010120000000000002 34.33333333333333
# parameter combination 0.010120000000000002 37.46666666666667
# parameter combination 0.010120000000000002 40.6
# parameter combination 0.010120000000000002 43.733333333333334
# parameter combination 0.010120000000000002 46.86666666666667
# parameter combination 0.010120000000000002 50.0
# parameter combination 0.011773333333333335 3.0
# parameter combination 0.011773333333333335 6.133333333333333
# parameter combination 0.011773333333333335 9.266666666666666
# parameter combination 0.011773333333333335 12.4
# parameter combination 0.011773333333333335 15.533333333333333
# parameter combination 0.011773333333333335 18.666666666666664
# parameter combination 0.011773333333333335 21.8
# parameter combination 0.011773333333333335 24.933333333333334
# parameter combination 0.011773333333333335 28.066666666666666
# parameter combination 0.011773333333333335 31.2
# parameter combination 0.011773333333333335 34.33333333333333
# parameter combination 0.011773333333333335 37.46666666666667
# parameter combination 0.011773333333333335 40.6
# parameter combination 0.011773333333333335 43.733333333333334
# parameter combination 0.011773333333333335 46.86666666666667
# parameter combination 0.011773333333333335 50.0
# parameter combination 0.013426666666666668 3.0
# parameter combination 0.013426666666666668 6.133333333333333
# parameter combination 0.013426666666666668 9.266666666666666
# parameter combination 0.013426666666666668 12.4
# parameter combination 0.013426666666666668 15.533333333333333
# parameter combination 0.013426666666666668 18.666666666666664
# parameter combination 0.013426666666666668 21.8
# parameter combination 0.013426666666666668 24.933333333333334
# parameter combination 0.013426666666666668 28.066666666666666
# parameter combination 0.013426666666666668 31.2
# parameter combination 0.013426666666666668 34.33333333333333
# parameter combination 0.013426666666666668 37.46666666666667
# parameter combination 0.013426666666666668 40.6
# parameter combination 0.013426666666666668 43.733333333333334
# parameter combination 0.013426666666666668 46.86666666666667
# parameter combination 0.013426666666666668 50.0
# parameter combination 0.015080000000000001 3.0
# parameter combination 0.015080000000000001 6.133333333333333
# parameter combination 0.015080000000000001 9.266666666666666
# parameter combination 0.015080000000000001 12.4
# parameter combination 0.015080000000000001 15.533333333333333
# parameter combination 0.015080000000000001 18.666666666666664
# parameter combination 0.015080000000000001 21.8
# parameter combination 0.015080000000000001 24.933333333333334
# parameter combination 0.015080000000000001 28.066666666666666
# parameter combination 0.015080000000000001 31.2
# parameter combination 0.015080000000000001 34.33333333333333
# parameter combination 0.015080000000000001 37.46666666666667
# parameter combination 0.015080000000000001 40.6
# parameter combination 0.015080000000000001 43.733333333333334
# parameter combination 0.015080000000000001 46.86666666666667
# parameter combination 0.015080000000000001 50.0
# parameter combination 0.016733333333333333 3.0
# parameter combination 0.016733333333333333 6.133333333333333
# parameter combination 0.016733333333333333 9.266666666666666
# parameter combination 0.016733333333333333 12.4
# parameter combination 0.016733333333333333 15.533333333333333
# parameter combination 0.016733333333333333 18.666666666666664
# parameter combination 0.016733333333333333 21.8
# parameter combination 0.016733333333333333 24.933333333333334
# parameter combination 0.016733333333333333 28.066666666666666
# parameter combination 0.016733333333333333 31.2
# parameter combination 0.016733333333333333 34.33333333333333
# parameter combination 0.016733333333333333 37.46666666666667
# parameter combination 0.025 9.266666666666666
# parameter combination 0.025 12.4
# parameter combination 0.025 15.533333333333333
# parameter combination 0.025 18.666666666666664
# parameter combination 0.025 21.8
# parameter combination 0.025 24.933333333333334
# parameter combination 0.025 28.066666666666666
# parameter combination 0.025 31.2
# parameter combination 0.025 34.33333333333333
# parameter combination 0.025 37.46666666666667
# parameter combination 0.025 40.6
# parameter combination 0.025 43.733333333333334
# parameter combination 0.025 46.86666666666667
# parameter combination 0.025 50.0
# run finished...

# %%
b_sls.interact()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…

# %%
fig, ax = plt.subplots()
b_sls.dp.mc.plot_mk(ax)
fig.savefig('sls_carbon_rho_0.005_ld_7_mc.pdf')
fig

# %%
fig, ax = plt.subplots()
b_sls.dp.plot_fw_with_fmax(ax)
fig.savefig('sls_carbon_rho_0.005_ld_7_fw.pdf')
fig
# Out:
# V_Rm_c = 342.76 kN, Shear failure by F_tot_max = 685.52 kN

# %%
fig = b_sls.dp.mc.plot_M_rho_and_stress_rho(n_rho = 30)
fig.savefig('sls_study_C40_M_max_rho.pdf')

# %%
params_config = [
#     ['f_ctm', b_sls, [1* EC2.get_f_ctm_fl(b_sls.f_ck, 300), 2* EC2.get_f_ctm_fl(b_sls.f_ck, 300)]],
#     ['f_ctm', b_sls, [1* EC2.get_f_ctm(b_sls.f_ck), 2* EC2.get_f_ctm(b_sls.f_ck), 3* EC2.get_f_ctm(b_sls.f_ck)]],
#     [['f_ck', b_sls, [30, 50, 70]], ['f_ctm', b_sls, [7.5, 10.58, 12]]],
#     [['f_ck', b_sls, [30, 70]], ['f_ctm', b_sls, [0, 0]]],
#         [['f_ck', b_sls, [10]], ['f_ctm', b_sls, [4]]],
#     ['f_ck', b_sls, [40, 70, 100]],
#     ['sls_to_uls_ratio', b_sls, [0.51, 0.59, 0.68]]
    ['concrete_law', b_sls, ['EC2 with plateau', 'EC2']],
#     ['n_i', b_sls, [5, 11, 15]],
#     ['dense_quarter', b_sls, [True, False]],
#     ['use_f_ctm_fl', b_sls, [True, False]],
#     ['apply_material_factors', b_sls, [True, False]],
#     ['rein_type', b_sls, ['carbon_grid', 'carbon_rebars']],
#     ['H', b_sls.dp.mc.cross_section_shape_, [200, 400, 600]],
#     ['B', b_sls.dp.mc.cross_section_shape_, [1000, 500, 200]],
#     [['B', b_sls.dp.mc.cross_section_shape_, [1000, 200, 300]], ['H', b_sls.dp.mc.cross_section_shape_, [300, 400, 700]]],
]
fig = ps.run(params_config, savefig=True)
# fig.savefig('sls_carbon_grid_factors_off.pdf')
# Out:
# Parametric study is running...
# concrete_law: (EC2 with plateau), parameter combination 0.0002 3.0
# parameter combination 0.0002 6.133333333333333
# parameter combination 0.0002 9.266666666666666
# parameter combination 0.0002 12.4
# parameter combination 0.0002 15.533333333333333
# parameter combination 0.0002 18.666666666666664
# parameter combination 0.0002 21.8
# parameter combination 0.0002 24.933333333333334
# parameter combination 0.0002 28.066666666666666
# parameter combination 0.0002 31.2
# parameter combination 0.0002 34.33333333333333
# parameter combination 0.0002 37.46666666666667
# parameter combination 0.015080000000000001 18.666666666666664
# parameter combination 0.015080000000000001 21.8
# parameter combination 0.015080000000000001 24.933333333333334
# parameter combination 0.015080000000000001 28.066666666666666
# parameter combination 0.015080000000000001 31.2
# parameter combination 0.015080000000000001 34.33333333333333
# parameter combination 0.015080000000000001 37.46666666666667
# parameter combination 0.015080000000000001 40.6
# parameter combination 0.015080000000000001 43.733333333333334
# parameter combination 0.015080000000000001 46.86666666666667
# parameter combination 0.015080000000000001 50.0
# parameter combination 0.016733333333333333 3.0
# parameter combination 0.016733333333333333 6.133333333333333
# parameter combination 0.016733333333333333 9.266666666666666
# parameter combination 0.016733333333333333 12.4
# parameter combination 0.016733333333333333 15.533333333333333
# parameter combination 0.016733333333333333 18.666666666666664
# parameter combination 0.016733333333333333 21.8
# parameter combination 0.016733333333333333 24.933333333333334
# parameter combination 0.016733333333333333 28.066666666666666
# parameter combination 0.016733333333333333 31.2
# parameter combination 0.016733333333333333 34.33333333333333
# parameter combination 0.016733333333333333 37.46666666666667
# parameter combination 0.016733333333333333 40.6
# parameter combination 0.016733333333333333 43.733333333333334
# parameter combination 0.016733333333333333 46.86666666666667
# parameter combination 0.016733333333333333 50.0
# parameter combination 0.018386666666666666 3.0
# parameter combination 0.018386666666666666 6.133333333333333
# parameter combination 0.018386666666666666 9.266666666666666
# parameter combination 0.018386666666666666 12.4
# parameter combination 0.018386666666666666 15.533333333333333
# parameter combination 0.018386666666666666 18.666666666666664
# parameter combination 0.018386666666666666 21.8
# parameter combination 0.018386666666666666 24.933333333333334
# parameter combination 0.018386666666666666 28.066666666666666
# parameter combination 0.018386666666666666 31.2
# parameter combination 0.018386666666666666 34.33333333333333
# parameter combination 0.018386666666666666 37.46666666666667
# parameter combination 0.018386666666666666 40.6
# parameter combination 0.018386666666666666 43.733333333333334
# parameter combination 0.018386666666666666 46.86666666666667
# parameter combination 0.018386666666666666 50.0
# parameter combination 0.020040000000000002 3.0
# parameter combination 0.020040000000000002 6.133333333333333
# parameter combination 0.020040000000000002 9.266666666666666
# parameter combination 0.020040000000000002 12.4
# parameter combination 0.020040000000000002 15.533333333333333
# parameter combination 0.020040000000000002 18.666666666666664
# parameter combination 0.020040000000000002 21.8
# parameter combination 0.020040000000000002 24.933333333333334
# parameter combination 0.020040000000000002 28.066666666666666
# parameter combination 0.020040000000000002 31.2
# parameter combination 0.020040000000000002 34.33333333333333
# parameter combination 0.020040000000000002 37.46666666666667
# parameter combination 0.020040000000000002 40.6
# parameter combination 0.020040000000000002 43.733333333333334
# parameter combination 0.020040000000000002 46.86666666666667
# parameter combination 0.020040000000000002 50.0
# parameter combination 0.021693333333333335 3.0
# parameter combination 0.021693333333333335 6.133333333333333
# parameter combination 0.021693333333333335 9.266666666666666
# parameter combination 0.021693333333333335 12.4
# parameter combination 0.021693333333333335 15.533333333333333
# parameter combination 0.021693333333333335 18.666666666666664
# parameter combination 0.021693333333333335 21.8
# parameter combination 0.021693333333333335 24.933333333333334
# parameter combination 0.021693333333333335 28.066666666666666
# parameter combination 0.021693333333333335 31.2
# parameter combination 0.021693333333333335 34.33333333333333
# parameter combination 0.021693333333333335 37.46666666666667
# parameter combination 0.021693333333333335 40.6
# parameter combination 0.021693333333333335 43.733333333333334
# parameter combination 0.021693333333333335 46.86666666666667
# parameter combination 0.021693333333333335 50.0
# parameter combination 0.02334666666666667 3.0
# parameter combination 0.02334666666666667 6.133333333333333
# parameter combination 0.02334666666666667 9.266666666666666
# parameter combination 0.02334666666666667 12.4
# parameter combination 0.02334666666666667 15.533333333333333
# parameter combination 0.02334666666666667 18.666666666666664
# parameter combination 0.02334666666666667 21.8
# parameter combination 0.02334666666666667 24.933333333333334
# parameter combination 0.02334666666666667 28.066666666666666
# parameter combination 0.02334666666666667 31.2
# parameter combination 0.02334666666666667 34.33333333333333
# parameter combination 0.02334666666666667 37.46666666666667
# parameter combination 0.02334666666666667 40.6
# parameter combination 0.02334666666666667 43.733333333333334
# parameter combination 0.02334666666666667 46.86666666666667
# parameter combination 0.02334666666666667 50.0
# parameter combination 0.025 3.0
# parameter combination 0.025 6.133333333333333
# parameter combination 0.025 9.266666666666666
# parameter combination 0.025 12.4
# parameter combination 0.025 15.533333333333333
# parameter combination 0.025 18.666666666666664
# parameter combination 0.025 21.8
# parameter combination 0.025 24.933333333333334
# parameter combination 0.025 28.066666666666666
# parameter combination 0.025 31.2
# parameter combination 0.025 34.33333333333333
# parameter combination 0.025 37.46666666666667
# parameter combination 0.025 40.6
# parameter combination 0.025 43.733333333333334
# parameter combination 0.025 46.86666666666667
# parameter combination 0.025 50.0
# dp updated!
# (EC2), parameter combination 0.0002 3.0
# parameter combination 0.0002 6.133333333333333
# parameter combination 0.0002 9.266666666666666
# parameter combination 0.0002 12.4
# parameter combination 0.0002 15.533333333333333
# parameter combination 0.0002 18.666666666666664
# parameter combination 0.0002 21.8
# parameter combination 0.0002 24.933333333333334
# parameter combination 0.0002 28.066666666666666
# parameter combination 0.0002 31.2
# parameter combination 0.0002 34.33333333333333
# parameter combination 0.0002 37.46666666666667
# parameter combination 0.0002 40.6
# parameter combination 0.0002 43.733333333333334
# parameter combination 0.0002 46.86666666666667
# parameter combination 0.0002 50.0
# parameter combination 0.0018533333333333336 3.0
# parameter combination 0.0018533333333333336 6.133333333333333
# parameter combination 0.0018533333333333336 9.266666666666666
# parameter combination 0.0018533333333333336 12.4
# parameter combination 0.0018533333333333336 15.533333333333333
# parameter combination 0.0018533333333333336 18.666666666666664
# parameter combination 0.0018533333333333336 21.8
# parameter combination 0.0018533333333333336 24.933333333333334
# parameter combination 0.0018533333333333336 28.066666666666666
# parameter combination 0.0018533333333333336 31.2
# parameter combination 0.0018533333333333336 34.33333333333333
# parameter combination 0.0018533333333333336 37.46666666666667
# parameter combination 0.0018533333333333336 40.6
# parameter combination 0.0018533333333333336 43.733333333333334
# parameter combination 0.0018533333333333336 46.86666666666667
# parameter combination 0.0018533333333333336 50.0
# parameter combination 0.003506666666666667 3.0
# parameter combination 0.003506666666666667 6.133333333333333
# parameter combination 0.003506666666666667 9.266666666666666
# parameter combination 0.003506666666666667 12.4
# parameter combination 0.003506666666666667 15.533333333333333
# parameter combination 0.010120000000000002 31.2
# parameter combination 0.010120000000000002 34.33333333333333
# parameter combination 0.010120000000000002 37.46666666666667
# parameter combination 0.010120000000000002 40.6
# parameter combination 0.010120000000000002 43.733333333333334
# parameter combination 0.010120000000000002 46.86666666666667
# parameter combination 0.010120000000000002 50.0
# parameter combination 0.011773333333333335 3.0
# parameter combination 0.011773333333333335 6.133333333333333
# parameter combination 0.011773333333333335 9.266666666666666
# parameter combination 0.011773333333333335 12.4
# parameter combination 0.011773333333333335 15.533333333333333
# parameter combination 0.011773333333333335 18.666666666666664
# parameter combination 0.011773333333333335 21.8
# parameter combination 0.011773333333333335 24.933333333333334
# parameter combination 0.011773333333333335 28.066666666666666
# parameter combination 0.011773333333333335 31.2
# parameter combination 0.011773333333333335 34.33333333333333
# parameter combination 0.011773333333333335 37.46666666666667
# parameter combination 0.011773333333333335 40.6
# parameter combination 0.011773333333333335 43.733333333333334
# parameter combination 0.011773333333333335 46.86666666666667
# parameter combination 0.011773333333333335 50.0
# parameter combination 0.013426666666666668 3.0
# parameter combination 0.013426666666666668 6.133333333333333
# parameter combination 0.013426666666666668 9.266666666666666
# parameter combination 0.013426666666666668 12.4
# parameter combination 0.013426666666666668 15.533333333333333
# parameter combination 0.013426666666666668 18.666666666666664
# parameter combination 0.013426666666666668 21.8
# parameter combination 0.013426666666666668 24.933333333333334
# parameter combination 0.013426666666666668 28.066666666666666
# parameter combination 0.013426666666666668 31.2
# parameter combination 0.013426666666666668 34.33333333333333
# parameter combination 0.013426666666666668 37.46666666666667
# parameter combination 0.013426666666666668 40.6
# parameter combination 0.013426666666666668 43.733333333333334
# parameter combination 0.013426666666666668 46.86666666666667
# parameter combination 0.013426666666666668 50.0
# parameter combination 0.015080000000000001 3.0
# parameter combination 0.015080000000000001 6.133333333333333
# parameter combination 0.015080000000000001 9.266666666666666
# parameter combination 0.015080000000000001 12.4
# parameter combination 0.015080000000000001 15.533333333333333
# parameter combination 0.015080000000000001 18.666666666666664
# parameter combination 0.015080000000000001 21.8
# parameter combination 0.015080000000000001 24.933333333333334
# parameter combination 0.015080000000000001 28.066666666666666
# parameter combination 0.015080000000000001 31.2
# parameter combination 0.015080000000000001 34.33333333333333
# parameter combination 0.015080000000000001 37.46666666666667
# parameter combination 0.015080000000000001 40.6
# parameter combination 0.015080000000000001 43.733333333333334
# parameter combination 0.015080000000000001 46.86666666666667
# parameter combination 0.015080000000000001 50.0
# parameter combination 0.016733333333333333 3.0
# parameter combination 0.016733333333333333 6.133333333333333
# parameter combination 0.016733333333333333 9.266666666666666
# parameter combination 0.016733333333333333 12.4
# parameter combination 0.016733333333333333 15.533333333333333
# parameter combination 0.016733333333333333 18.666666666666664
# parameter combination 0.016733333333333333 21.8
# parameter combination 0.016733333333333333 24.933333333333334
# parameter combination 0.016733333333333333 28.066666666666666
# parameter combination 0.016733333333333333 31.2
# parameter combination 0.016733333333333333 34.33333333333333
# parameter combination 0.016733333333333333 37.46666666666667
# parameter combination 0.016733333333333333 40.6
# parameter combination 0.016733333333333333 43.733333333333334
# parameter combination 0.025 18.666666666666664
# parameter combination 0.025 21.8
# parameter combination 0.025 24.933333333333334
# parameter combination 0.025 28.066666666666666
# parameter combination 0.025 31.2
# parameter combination 0.025 34.33333333333333
# parameter combination 0.025 37.46666666666667
# parameter combination 0.025 40.6
# parameter combination 0.025 43.733333333333334
# parameter combination 0.025 46.86666666666667
# parameter combination 0.025 50.0
# dp updated!
#
# Parametric study finished.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig.savefig('sls_carbon_grid_factors_off_concrete_law.pdf')

# %%
# sls.plot_F_u()
sls.plot_F_u(bending_shear_diff = True)
# sls.plot_F_u(load='shear')

# %% [markdown]
# ## Steel

# %%
b_sls2 = BeamSLSCurve(n_i = 16, rein_type = 'steel', f_ck=40) #, rein_type = 'steel'
ps2 = SLSParamStudy(b_sls2)
b_sls2.run()
# Out:
# dp updated!
# run started...
# parameter combination 0.0002 3.0
# parameter combination 0.0002 6.133333333333333
# parameter combination 0.0002 9.266666666666666
# parameter combination 0.0002 12.4
# parameter combination 0.0002 15.533333333333333
# parameter combination 0.0002 18.666666666666664
# parameter combination 0.0002 21.8
# parameter combination 0.0002 24.933333333333334
# parameter combination 0.0002 28.066666666666666
# parameter combination 0.0002 31.2
# parameter combination 0.0002 34.33333333333333
# parameter combination 0.0002 37.46666666666667
# parameter combination 0.0002 40.6
# parameter combination 0.0002 43.733333333333334
# parameter combination 0.0002 46.86666666666667
# parameter combination 0.0002 50.0
# parameter combination 0.0018533333333333336 3.0
# parameter combination 0.0018533333333333336 6.133333333333333
# parameter combination 0.0018533333333333336 9.266666666666666
# parameter combination 0.0018533333333333336 12.4
# parameter combination 0.0018533333333333336 15.533333333333333
# parameter combination 0.0018533333333333336 18.666666666666664
# parameter combination 0.0018533333333333336 21.8
# parameter combination 0.0018533333333333336 24.933333333333334
# parameter combination 0.0018533333333333336 28.066666666666666
# parameter combination 0.0018533333333333336 31.2
# parameter combination 0.0018533333333333336 34.33333333333333
# parameter combination 0.0018533333333333336 37.46666666666667
# parameter combination 0.0018533333333333336 40.6
# parameter combination 0.0018533333333333336 43.733333333333334
# parameter combination 0.0018533333333333336 46.86666666666667
# parameter combination 0.0018533333333333336 50.0
# parameter combination 0.003506666666666667 3.0
# parameter combination 0.003506666666666667 6.133333333333333
# parameter combination 0.003506666666666667 9.266666666666666
# parameter combination 0.003506666666666667 12.4
# parameter combination 0.003506666666666667 15.533333333333333
# parameter combination 0.003506666666666667 18.666666666666664
# parameter combination 0.003506666666666667 21.8
# parameter combination 0.003506666666666667 24.933333333333334
# parameter combination 0.003506666666666667 28.066666666666666
# parameter combination 0.003506666666666667 31.2
# parameter combination 0.003506666666666667 34.33333333333333
# parameter combination 0.003506666666666667 37.46666666666667
# parameter combination 0.003506666666666667 40.6
# parameter combination 0.003506666666666667 43.733333333333334
# parameter combination 0.003506666666666667 46.86666666666667
# parameter combination 0.003506666666666667 50.0
# parameter combination 0.0051600000000000005 3.0
# parameter combination 0.0051600000000000005 6.133333333333333
# parameter combination 0.0051600000000000005 9.266666666666666
# parameter combination 0.0051600000000000005 12.4
# parameter combination 0.011773333333333335 31.2
# parameter combination 0.011773333333333335 34.33333333333333
# parameter combination 0.011773333333333335 37.46666666666667
# parameter combination 0.011773333333333335 40.6
# parameter combination 0.011773333333333335 43.733333333333334
# parameter combination 0.011773333333333335 46.86666666666667
# parameter combination 0.011773333333333335 50.0
# parameter combination 0.013426666666666668 3.0
# parameter combination 0.013426666666666668 6.133333333333333
# parameter combination 0.013426666666666668 9.266666666666666
# parameter combination 0.013426666666666668 12.4
# parameter combination 0.013426666666666668 15.533333333333333
# parameter combination 0.013426666666666668 18.666666666666664
# parameter combination 0.013426666666666668 21.8
# parameter combination 0.013426666666666668 24.933333333333334
# parameter combination 0.013426666666666668 28.066666666666666
# parameter combination 0.013426666666666668 31.2
# parameter combination 0.013426666666666668 34.33333333333333
# parameter combination 0.013426666666666668 37.46666666666667
# parameter combination 0.013426666666666668 40.6
# parameter combination 0.013426666666666668 43.733333333333334
# parameter combination 0.013426666666666668 46.86666666666667
# parameter combination 0.013426666666666668 50.0
# parameter combination 0.015080000000000001 3.0
# parameter combination 0.015080000000000001 6.133333333333333
# parameter combination 0.015080000000000001 9.266666666666666
# parameter combination 0.015080000000000001 12.4
# parameter combination 0.015080000000000001 15.533333333333333
# parameter combination 0.015080000000000001 18.666666666666664
# parameter combination 0.015080000000000001 21.8
# parameter combination 0.015080000000000001 24.933333333333334
# parameter combination 0.015080000000000001 28.066666666666666
# parameter combination 0.015080000000000001 31.2
# parameter combination 0.015080000000000001 34.33333333333333
# parameter combination 0.015080000000000001 37.46666666666667
# parameter combination 0.015080000000000001 40.6
# parameter combination 0.015080000000000001 43.733333333333334
# parameter combination 0.015080000000000001 46.86666666666667
# parameter combination 0.015080000000000001 50.0
# parameter combination 0.016733333333333333 3.0
# parameter combination 0.016733333333333333 6.133333333333333
# parameter combination 0.016733333333333333 9.266666666666666
# parameter combination 0.016733333333333333 12.4
# parameter combination 0.016733333333333333 15.533333333333333
# parameter combination 0.016733333333333333 18.666666666666664
# parameter combination 0.016733333333333333 21.8
# parameter combination 0.016733333333333333 24.933333333333334
# parameter combination 0.016733333333333333 28.066666666666666
# parameter combination 0.016733333333333333 31.2
# parameter combination 0.016733333333333333 34.33333333333333
# parameter combination 0.016733333333333333 37.46666666666667
# parameter combination 0.016733333333333333 40.6
# parameter combination 0.016733333333333333 43.733333333333334
# parameter combination 0.016733333333333333 46.86666666666667
# parameter combination 0.016733333333333333 50.0
# parameter combination 0.018386666666666666 3.0
# parameter combination 0.018386666666666666 6.133333333333333
# parameter combination 0.018386666666666666 9.266666666666666
# parameter combination 0.018386666666666666 12.4
# parameter combination 0.018386666666666666 15.533333333333333
# parameter combination 0.018386666666666666 18.666666666666664
# parameter combination 0.018386666666666666 21.8
# parameter combination 0.018386666666666666 24.933333333333334
# parameter combination 0.018386666666666666 28.066666666666666
# parameter combination 0.018386666666666666 31.2
# parameter combination 0.018386666666666666 34.33333333333333
# parameter combination 0.018386666666666666 37.46666666666667
# parameter combination 0.018386666666666666 40.6
# parameter combination 0.018386666666666666 43.733333333333334
# parameter combination 0.018386666666666666 46.86666666666667
# parameter combination 0.018386666666666666 50.0
# parameter combination 0.020040000000000002 3.0
# parameter combination 0.020040000000000002 6.133333333333333
# parameter combination 0.020040000000000002 9.266666666666666
# parameter combination 0.020040000000000002 12.4
# parameter combination 0.020040000000000002 15.533333333333333
# parameter combination 0.020040000000000002 18.666666666666664
# parameter combination 0.020040000000000002 21.8
# parameter combination 0.020040000000000002 24.933333333333334
# parameter combination 0.020040000000000002 28.066666666666666
# parameter combination 0.020040000000000002 31.2
# parameter combination 0.020040000000000002 34.33333333333333
# parameter combination 0.020040000000000002 37.46666666666667
# parameter combination 0.020040000000000002 40.6
# parameter combination 0.020040000000000002 43.733333333333334
# parameter combination 0.020040000000000002 46.86666666666667
# parameter combination 0.020040000000000002 50.0
# parameter combination 0.021693333333333335 3.0
# parameter combination 0.021693333333333335 6.133333333333333
# parameter combination 0.021693333333333335 9.266666666666666
# parameter combination 0.021693333333333335 12.4
# parameter combination 0.021693333333333335 15.533333333333333
# parameter combination 0.021693333333333335 18.666666666666664
# parameter combination 0.021693333333333335 21.8
# parameter combination 0.021693333333333335 24.933333333333334
# parameter combination 0.021693333333333335 28.066666666666666
# parameter combination 0.021693333333333335 31.2
# parameter combination 0.021693333333333335 34.33333333333333
# parameter combination 0.021693333333333335 37.46666666666667
# parameter combination 0.021693333333333335 40.6
# parameter combination 0.021693333333333335 43.733333333333334
# parameter combination 0.021693333333333335 46.86666666666667
# parameter combination 0.021693333333333335 50.0
# parameter combination 0.02334666666666667 3.0
# parameter combination 0.02334666666666667 6.133333333333333
# parameter combination 0.02334666666666667 9.266666666666666
# parameter combination 0.02334666666666667 12.4
# parameter combination 0.02334666666666667 15.533333333333333
# parameter combination 0.02334666666666667 18.666666666666664
# parameter combination 0.02334666666666667 21.8
# parameter combination 0.02334666666666667 24.933333333333334
# parameter combination 0.02334666666666667 28.066666666666666
# parameter combination 0.02334666666666667 31.2
# parameter combination 0.02334666666666667 34.33333333333333
# parameter combination 0.02334666666666667 37.46666666666667
# parameter combination 0.02334666666666667 40.6
# parameter combination 0.02334666666666667 43.733333333333334
# parameter combination 0.02334666666666667 46.86666666666667
# parameter combination 0.02334666666666667 50.0
# parameter combination 0.025 3.0
# parameter combination 0.025 6.133333333333333
# parameter combination 0.025 9.266666666666666
# parameter combination 0.025 12.4
# parameter combination 0.025 15.533333333333333
# parameter combination 0.025 18.666666666666664
# parameter combination 0.025 21.8
# parameter combination 0.025 24.933333333333334
# parameter combination 0.025 28.066666666666666
# parameter combination 0.025 31.2
# parameter combination 0.025 34.33333333333333
# parameter combination 0.025 37.46666666666667
# parameter combination 0.025 40.6
# parameter combination 0.025 43.733333333333334
# parameter combination 0.025 46.86666666666667
# parameter combination 0.025 50.0
# run finished...

# %%
b_sls2.interact()
# Out:
# VBox(children=(HBox(children=(VBox(children=(Tree(layout=Layout(align_items='stretch', border='solid 1px black…

# %%
params_config = [
    ['f_ck', b_sls2, [40]],
]
fig = ps2.run(params_config, savefig=True)
# fig.savefig('sls_steel_grid_factors_off.pdf')
# Out:
# Parametric study is running...
# f_ck: (40), parameter combination 0.0002 3.0
# parameter combination 0.0002 6.133333333333333
# parameter combination 0.0002 9.266666666666666
# parameter combination 0.0002 12.4
# parameter combination 0.0002 15.533333333333333
# parameter combination 0.0002 18.666666666666664
# parameter combination 0.0002 21.8
# parameter combination 0.0002 24.933333333333334
# parameter combination 0.0002 28.066666666666666
# parameter combination 0.0002 31.2
# parameter combination 0.0002 34.33333333333333
# parameter combination 0.0002 37.46666666666667
# parameter combination 0.0002 40.6
# parameter combination 0.0002 43.733333333333334
# parameter combination 0.0002 46.86666666666667
# parameter combination 0.0002 50.0
# parameter combination 0.0018533333333333336 3.0
# parameter combination 0.0018533333333333336 6.133333333333333
# parameter combination 0.0018533333333333336 9.266666666666666
# parameter combination 0.0018533333333333336 12.4
# parameter combination 0.0018533333333333336 15.533333333333333
# parameter combination 0.0018533333333333336 18.666666666666664
# parameter combination 0.0018533333333333336 21.8
# parameter combination 0.0018533333333333336 24.933333333333334
# parameter combination 0.0018533333333333336 28.066666666666666
# parameter combination 0.0018533333333333336 31.2
# parameter combination 0.0018533333333333336 34.33333333333333
# parameter combination 0.0018533333333333336 37.46666666666667
# parameter combination 0.0018533333333333336 40.6
# parameter combination 0.0018533333333333336 43.733333333333334
# parameter combination 0.0018533333333333336 46.86666666666667
# parameter combination 0.0018533333333333336 50.0
# parameter combination 0.003506666666666667 3.0
# parameter combination 0.003506666666666667 6.133333333333333
# parameter combination 0.003506666666666667 9.266666666666666
# parameter combination 0.003506666666666667 12.4
# parameter combination 0.003506666666666667 15.533333333333333
# parameter combination 0.003506666666666667 18.666666666666664
# parameter combination 0.003506666666666667 21.8
# parameter combination 0.003506666666666667 24.933333333333334
# parameter combination 0.003506666666666667 28.066666666666666
# parameter combination 0.003506666666666667 31.2
# parameter combination 0.003506666666666667 34.33333333333333
# parameter combination 0.003506666666666667 37.46666666666667
# parameter combination 0.003506666666666667 40.6
# parameter combination 0.003506666666666667 43.733333333333334
# parameter combination 0.003506666666666667 46.86666666666667
# parameter combination 0.003506666666666667 50.0
# parameter combination 0.0051600000000000005 3.0
# parameter combination 0.0051600000000000005 6.133333333333333
# parameter combination 0.0051600000000000005 9.266666666666666
# parameter combination 0.0051600000000000005 12.4
# parameter combination 0.0051600000000000005 15.533333333333333
# parameter combination 0.0051600000000000005 18.666666666666664
# parameter combination 0.0051600000000000005 21.8
# parameter combination 0.0051600000000000005 24.933333333333334
# parameter combination 0.0051600000000000005 28.066666666666666
# parameter combination 0.0051600000000000005 31.2
# parameter combination 0.0051600000000000005 34.33333333333333
# parameter combination 0.0051600000000000005 37.46666666666667
# parameter combination 0.0051600000000000005 40.6
# parameter combination 0.0051600000000000005 43.733333333333334
# parameter combination 0.0051600000000000005 46.86666666666667
# parameter combination 0.0051600000000000005 50.0
# parameter combination 0.006813333333333334 3.0
# parameter combination 0.006813333333333334 6.133333333333333
# parameter combination 0.006813333333333334 9.266666666666666
# parameter combination 0.006813333333333334 12.4
# parameter combination 0.006813333333333334 15.533333333333333
# parameter combination 0.006813333333333334 18.666666666666664
# parameter combination 0.006813333333333334 21.8
# parameter combination 0.006813333333333334 24.933333333333334
# parameter combination 0.006813333333333334 28.066666666666666
# parameter combination 0.006813333333333334 31.2
# parameter combination 0.006813333333333334 34.33333333333333
# parameter combination 0.006813333333333334 37.46666666666667
# parameter combination 0.006813333333333334 40.6
# parameter combination 0.006813333333333334 43.733333333333334
# parameter combination 0.006813333333333334 46.86666666666667
# parameter combination 0.006813333333333334 50.0
# parameter combination 0.008466666666666667 3.0
# parameter combination 0.008466666666666667 6.133333333333333
# parameter combination 0.008466666666666667 9.266666666666666
# parameter combination 0.008466666666666667 12.4
# parameter combination 0.008466666666666667 15.533333333333333
# parameter combination 0.008466666666666667 18.666666666666664
# parameter combination 0.008466666666666667 21.8
# parameter combination 0.008466666666666667 24.933333333333334
# parameter combination 0.008466666666666667 28.066666666666666
# parameter combination 0.008466666666666667 31.2
# parameter combination 0.008466666666666667 34.33333333333333
# parameter combination 0.008466666666666667 37.46666666666667
# parameter combination 0.008466666666666667 40.6
# parameter combination 0.008466666666666667 43.733333333333334
# parameter combination 0.008466666666666667 46.86666666666667
# parameter combination 0.008466666666666667 50.0
# parameter combination 0.010120000000000002 3.0
# parameter combination 0.010120000000000002 6.133333333333333
# parameter combination 0.010120000000000002 9.266666666666666
# parameter combination 0.010120000000000002 12.4
# parameter combination 0.010120000000000002 15.533333333333333
# parameter combination 0.010120000000000002 18.666666666666664
# parameter combination 0.010120000000000002 21.8
# parameter combination 0.010120000000000002 24.933333333333334
# parameter combination 0.010120000000000002 28.066666666666666
# parameter combination 0.010120000000000002 31.2
# parameter combination 0.010120000000000002 34.33333333333333
# parameter combination 0.010120000000000002 37.46666666666667
# parameter combination 0.010120000000000002 40.6
# parameter combination 0.010120000000000002 43.733333333333334
# parameter combination 0.010120000000000002 46.86666666666667
# parameter combination 0.010120000000000002 50.0
# parameter combination 0.011773333333333335 3.0
# parameter combination 0.011773333333333335 6.133333333333333
# parameter combination 0.011773333333333335 9.266666666666666
# parameter combination 0.011773333333333335 12.4
# parameter combination 0.011773333333333335 15.533333333333333
# parameter combination 0.011773333333333335 18.666666666666664
# parameter combination 0.011773333333333335 21.8
# parameter combination 0.011773333333333335 24.933333333333334
# parameter combination 0.011773333333333335 28.066666666666666
# parameter combination 0.011773333333333335 31.2
# parameter combination 0.011773333333333335 34.33333333333333
# parameter combination 0.011773333333333335 37.46666666666667
# parameter combination 0.011773333333333335 40.6
# parameter combination 0.011773333333333335 43.733333333333334
# parameter combination 0.011773333333333335 46.86666666666667
# parameter combination 0.011773333333333335 50.0
# parameter combination 0.013426666666666668 3.0
# parameter combination 0.013426666666666668 6.133333333333333
# parameter combination 0.013426666666666668 9.266666666666666
# parameter combination 0.013426666666666668 12.4
# parameter combination 0.013426666666666668 15.533333333333333
# parameter combination 0.013426666666666668 18.666666666666664
# parameter combination 0.013426666666666668 21.8
# parameter combination 0.013426666666666668 24.933333333333334
# parameter combination 0.013426666666666668 28.066666666666666
# parameter combination 0.013426666666666668 31.2
# parameter combination 0.013426666666666668 34.33333333333333
# parameter combination 0.013426666666666668 37.46666666666667
# parameter combination 0.013426666666666668 40.6
# parameter combination 0.013426666666666668 43.733333333333334
# parameter combination 0.013426666666666668 46.86666666666667
# parameter combination 0.013426666666666668 50.0
# parameter combination 0.015080000000000001 3.0
# parameter combination 0.015080000000000001 6.133333333333333
# parameter combination 0.015080000000000001 9.266666666666666
# parameter combination 0.015080000000000001 12.4
# parameter combination 0.015080000000000001 15.533333333333333
# parameter combination 0.015080000000000001 18.666666666666664
# parameter combination 0.015080000000000001 21.8
# parameter combination 0.015080000000000001 24.933333333333334
# parameter combination 0.015080000000000001 28.066666666666666
# parameter combination 0.015080000000000001 31.2
# parameter combination 0.015080000000000001 34.33333333333333
# parameter combination 0.015080000000000001 37.46666666666667
# parameter combination 0.015080000000000001 40.6
# parameter combination 0.015080000000000001 43.733333333333334
# parameter combination 0.015080000000000001 46.86666666666667
# parameter combination 0.015080000000000001 50.0
# parameter combination 0.016733333333333333 3.0
# parameter combination 0.016733333333333333 6.133333333333333
# parameter combination 0.016733333333333333 9.266666666666666
# parameter combination 0.016733333333333333 12.4
# parameter combination 0.016733333333333333 15.533333333333333
# parameter combination 0.016733333333333333 18.666666666666664
# parameter combination 0.016733333333333333 21.8
# parameter combination 0.016733333333333333 24.933333333333334
# parameter combination 0.016733333333333333 28.066666666666666
# parameter combination 0.016733333333333333 31.2
# parameter combination 0.016733333333333333 34.33333333333333
# parameter combination 0.016733333333333333 37.46666666666667
# parameter combination 0.016733333333333333 40.6
# parameter combination 0.016733333333333333 43.733333333333334
# parameter combination 0.016733333333333333 46.86666666666667
# parameter combination 0.016733333333333333 50.0
# parameter combination 0.018386666666666666 3.0
# parameter combination 0.018386666666666666 6.133333333333333
# parameter combination 0.018386666666666666 9.266666666666666
# parameter combination 0.018386666666666666 12.4
# parameter combination 0.018386666666666666 15.533333333333333
# parameter combination 0.018386666666666666 18.666666666666664
# parameter combination 0.018386666666666666 21.8
# parameter combination 0.018386666666666666 24.933333333333334
# parameter combination 0.018386666666666666 28.066666666666666
# parameter combination 0.018386666666666666 31.2
# parameter combination 0.018386666666666666 34.33333333333333
# parameter combination 0.018386666666666666 37.46666666666667
# parameter combination 0.018386666666666666 40.6
# parameter combination 0.018386666666666666 43.733333333333334
# parameter combination 0.018386666666666666 46.86666666666667
# parameter combination 0.018386666666666666 50.0
# parameter combination 0.020040000000000002 3.0
# parameter combination 0.020040000000000002 6.133333333333333
# parameter combination 0.020040000000000002 9.266666666666666
# parameter combination 0.020040000000000002 12.4
# parameter combination 0.020040000000000002 15.533333333333333
# parameter combination 0.020040000000000002 18.666666666666664
# parameter combination 0.020040000000000002 21.8
# parameter combination 0.020040000000000002 24.933333333333334
# parameter combination 0.020040000000000002 28.066666666666666
# parameter combination 0.020040000000000002 31.2
# parameter combination 0.020040000000000002 34.33333333333333
# parameter combination 0.020040000000000002 37.46666666666667
# parameter combination 0.020040000000000002 40.6
# parameter combination 0.020040000000000002 43.733333333333334
# parameter combination 0.020040000000000002 46.86666666666667
# parameter combination 0.020040000000000002 50.0
# parameter combination 0.021693333333333335 3.0
# parameter combination 0.021693333333333335 6.133333333333333
# parameter combination 0.021693333333333335 9.266666666666666
# parameter combination 0.021693333333333335 12.4
# parameter combination 0.021693333333333335 15.533333333333333
# parameter combination 0.021693333333333335 18.666666666666664
# parameter combination 0.021693333333333335 21.8
# parameter combination 0.021693333333333335 24.933333333333334
# parameter combination 0.021693333333333335 28.066666666666666
# parameter combination 0.021693333333333335 31.2
# parameter combination 0.021693333333333335 34.33333333333333
# parameter combination 0.021693333333333335 37.46666666666667
# parameter combination 0.021693333333333335 40.6
# parameter combination 0.021693333333333335 43.733333333333334
# parameter combination 0.021693333333333335 46.86666666666667
# parameter combination 0.021693333333333335 50.0
# parameter combination 0.02334666666666667 3.0
# parameter combination 0.02334666666666667 6.133333333333333
# parameter combination 0.02334666666666667 9.266666666666666
# parameter combination 0.02334666666666667 12.4
# parameter combination 0.02334666666666667 15.533333333333333
# parameter combination 0.02334666666666667 18.666666666666664
# parameter combination 0.02334666666666667 21.8
# parameter combination 0.02334666666666667 24.933333333333334
# parameter combination 0.02334666666666667 28.066666666666666
# parameter combination 0.02334666666666667 31.2
# parameter combination 0.02334666666666667 34.33333333333333
# parameter combination 0.02334666666666667 37.46666666666667
# parameter combination 0.02334666666666667 40.6
# parameter combination 0.02334666666666667 43.733333333333334
# parameter combination 0.02334666666666667 46.86666666666667
# parameter combination 0.02334666666666667 50.0
# parameter combination 0.025 3.0
# parameter combination 0.025 6.133333333333333
# parameter combination 0.025 9.266666666666666
# parameter combination 0.025 12.4
# parameter combination 0.025 15.533333333333333
# parameter combination 0.025 18.666666666666664
# parameter combination 0.025 21.8
# parameter combination 0.025 24.933333333333334
# parameter combination 0.025 28.066666666666666
# parameter combination 0.025 31.2
# parameter combination 0.025 34.33333333333333
# parameter combination 0.025 37.46666666666667
# parameter combination 0.025 40.6
# parameter combination 0.025 43.733333333333334
# parameter combination 0.025 46.86666666666667
# parameter combination 0.025 50.0
#
# Parametric study finished.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
b_sls2.dp.mc.plot_mk(ax)
fig.savefig('sls_steel_rho_0.005_ld_7_mc.pdf')
fig

# %%
fig, ax = plt.subplots()
b_sls2.dp.plot_fw_with_fmax(ax)
fig.savefig('sls_steel_rho_0.005_ld_7_fw.pdf')
fig

# %% [markdown]
# ## Tensile vs compression failure zones

# %%
dp = b_sls.dp
mc = dp.mc
# for rho in b_sls.rho_range:
#     area_g = mc.cross_section_shape_.get_cs_area()
#     A_j_g = rho * area_g
#     mc.cross_section_layout.items[0].A = A_j_g
#     mc.M_t / mc.M_scale

# %%
from matplotlib import cm
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(b_sls.rho_grid, b_sls.sl_grid, b_sls.F_u_grid,
                       linewidth=0, antialiased=False, cmap=cm.coolwarm)
fig

# %%
np.linspace(0, 5000, 30)
fig, ax = plt.subplots()
# z = b_sls.F_u_grid / b_sls.F_s_grid - 1. / b_sls.sls_to_uls_ratio
z = b_sls.F_u_grid
cs = ax.contour(b_sls.rho_grid, b_sls.sl_grid, z, levels=[0, 10, 20, 50, 80, 100, 150, 300, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000])
ax.clabel(cs, inline=True, fontsize=10)
fig
