# %% [markdown]
# # Deflection profile interactive model

# %%
from bmcs_beam.beam_design.mk_profile import MomentCurvatureProfile
import bmcs_utils.api as bu

mk = MomentCurvatureProfile()
bu.InteractiveWindow(mk).interact()
